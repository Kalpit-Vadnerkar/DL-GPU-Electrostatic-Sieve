# %%
import os
import pandas as pd

Folder_name = "Sample Dataset"
File_name = "data_set_main1.txt"

File_path = os.path.join(Folder_name, File_name)
# Open the file
file = open(File_path, 'r')

# Split the text data into lines
lines = file.readlines()

# Extract the column names from the header line
column_names = lines[0].strip().split('|')
column_names = [col.strip() for col in column_names]

# Create a list of rows
rows = []
for line in lines[2:]:  # Skip the header and column names lines
    if line.strip():
        row = line.strip().split()
        rows.append(row)

# Create a pandas DataFrame from the list of rows
data = pd.DataFrame(rows, columns=column_names)

# Convert the data types of the columns
data = data.astype({
    'absolute angle of inclination': float, 'angle of inclination': float, 'number of electrodes': float,
    'voltage magnitude': float, 'voltage frequency': float,'electrode dimension': float,
    'x pitch': float, 'number of phases': float, 'grain mass density': float,
    'mesh size': float, 'gravity': float, 'phase shift': float,
    'maximum classified radius': float,'distance between dust generation and first electrode': float,
    'yield': float
})

data
# Out:
#      absolute angle of inclination  angle of inclination  \
# 0                            355.0                   5.0
# 1                            355.0                   5.0
# 2                            355.0                   5.0
# 3                            355.0                   5.0
# 4                            355.0                   5.0
# ..                             ...                   ...
# 636                          285.0                  75.0
# 637                          285.0                  75.0
# 638                          285.0                  75.0
# 639                          285.0                  75.0
# 640                          285.0                  75.0
#
#      number of electrodes  voltage magnitude  voltage frequency  \
# 0                     3.0             1000.0               10.0
# 1                     4.0             1000.0               10.0
# 2                     5.0             1000.0               10.0
# 3                     6.0             1000.0               10.0
# 4                     2.0             1000.0               10.0
# ..                    ...                ...                ...
# 636                   3.0             1000.0               10.0
# 637                   4.0             1000.0               10.0
# 638                   5.0             1000.0               10.0
# 639                   6.0             1000.0               10.0
# 640                   2.0             1000.0               10.0
#
#      electrode dimension  x pitch  number of phases  grain mass density  \
# 0                    2.0     20.0               4.0              2650.0
# 1                    2.0     20.0               4.0              2650.0
# 2                    2.0     20.0               4.0              2650.0
# 3                    2.0     20.0               4.0              2650.0
# 4                    3.0     20.0               4.0              2650.0
# ..                   ...      ...               ...                 ...
# 636                  4.0     30.0               4.0              2650.0
# 637                  4.0     30.0               4.0              2650.0
# 638                  4.0     30.0               4.0              2650.0
# 639                  4.0     30.0               4.0              2650.0
# 640                  5.0     35.0               4.0              2650.0
#
#      mesh size  gravity  phase shift  maximum classified radius  \
# 0        0.001     9.81         90.0                    0.00001
# 1        0.001     9.81         90.0                    0.00001
# 2        0.001     9.81         90.0                    0.00001
# 3        0.001     9.81         90.0                    0.00001
# 4        0.001     9.81         90.0                    0.00001
# ..         ...      ...          ...                        ...
# 636      0.001     9.81         90.0                    0.00001
# 637      0.001     9.81         90.0                    0.00001
# 638      0.001     9.81         90.0                    0.00001
# 639      0.001     9.81         90.0                    0.00001
# 640      0.001     9.81         90.0                    0.00001
#
#      distance between dust generation and first electrode     yield
# 0                                             0.007250     0.126490
# 1                                             0.006375     0.092699
# 2                                             0.005500     0.082674
# 3                                             0.009626     0.175985
# 4                                             0.007625     0.356726
# ..                                                 ...          ...
# 636                                           0.061038     0.146419
# 637                                           0.060058     0.000000
# 638                                           0.059077     0.000034
# 639                                           0.063096     2.766215
# 640                                           0.072189     0.098258
#
# [641 rows x 15 columns]

# %%
data.info()
data.describe(include='all')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 641 entries, 0 to 640
# Data columns (total 15 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   absolute angle of inclination                         641 non-null    float64
#  1   angle of inclination                                  641 non-null    float64
#  2   number of electrodes                                  641 non-null    float64
#  3   voltage magnitude                                     641 non-null    float64
#  4   voltage frequency                                     641 non-null    float64
#  5   electrode dimension                                   641 non-null    float64
#  6   x pitch                                               641 non-null    float64
#  7   number of phases                                      641 non-null    float64
#  8   grain mass density                                    641 non-null    float64
#  9   mesh size                                             641 non-null    float64
#  10  gravity                                               641 non-null    float64
#  11  phase shift                                           641 non-null    float64
#  12  maximum classified radius                             641 non-null    float64
#  13  distance between dust generation and first electrode  641 non-null    float64
#  14  yield                                                 641 non-null    float64
# dtypes: float64(15)
# memory usage: 75.2 KB
#        absolute angle of inclination  angle of inclination  \
# count                     641.000000            641.000000
# mean                      320.748830             39.251170
# std                        21.266191             21.266191
# min                       285.000000              5.000000
# 25%                       305.000000             20.000000
# 50%                       320.000000             40.000000
# 75%                       340.000000             55.000000
# max                       355.000000             75.000000
#
#        number of electrodes  voltage magnitude  voltage frequency  \
# count            641.000000              641.0              641.0
# mean               3.951638             1000.0               10.0
# std                1.403957                0.0                0.0
# min                2.000000             1000.0               10.0
# 25%                3.000000             1000.0               10.0
# 50%                4.000000             1000.0               10.0
# 75%                5.000000             1000.0               10.0
# max                6.000000             1000.0               10.0
#
#        electrode dimension     x pitch  number of phases  grain mass density  \
# count           641.000000  641.000000             641.0               641.0
# mean              4.143526   24.867395               4.0              2650.0
# std               1.292282    6.721436               0.0                 0.0
# min               2.000000   20.000000               4.0              2650.0
# 25%               3.000000   20.000000               4.0              2650.0
# 50%               4.000000   20.000000               4.0              2650.0
# 75%               5.000000   30.000000               4.0              2650.0
# max               6.000000   40.000000               4.0              2650.0
#
#           mesh size       gravity  phase shift  maximum classified radius  \
# count  6.410000e+02  6.410000e+02        641.0                  641.00000
# mean   1.000000e-03  9.810000e+00         90.0                    0.00001
# std    2.170098e-19  1.777744e-15          0.0                    0.00000
# min    1.000000e-03  9.810000e+00         90.0                    0.00001
# 25%    1.000000e-03  9.810000e+00         90.0                    0.00001
# 50%    1.000000e-03  9.810000e+00         90.0                    0.00001
# 75%    1.000000e-03  9.810000e+00         90.0                    0.00001
# max    1.000000e-03  9.810000e+00         90.0                    0.00001
#
#        distance between dust generation and first electrode       yield
# count                                         641.000000     641.000000
# mean                                            0.018712       1.149210
# std                                             0.011707       0.745734
# min                                             0.003500       0.000000
# 25%                                             0.009962       0.595077
# 50%                                             0.015082       0.999666
# 75%                                             0.024359       1.643617
# max                                             0.072189       4.031617

# %%
import matplotlib.pyplot as plt

numeric_features = data.select_dtypes(include=['float64'])
numeric_features.hist(figsize=(15, 15))
plt.suptitle("Histograms of Numeric Features", fontsize=16)
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
